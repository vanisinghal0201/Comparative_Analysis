# %% [markdown]
# <a href="https://colab.research.google.com/github/vanisinghal0201/Comparative_Analysis/blob/master/Visualisations_for_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
import copy
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import matplotlib.pyplot as plt
import numpy as np
resultauc={"DATA 1":{"KNN":{"SMOTE":0.75,"ADAYSN":0.854,"ROS":0.958,"classweight":0.479},"LogisticR":{"SMOTE":0.812,"ADAYSN":0.812,"ROS":0.875,"classweight":0.454},"NaivesBayes":{"SMOTE":0.6875,"ADAYSN":0.75,"ROS":0.645,"classweight":0.695},"DecisionT":{"SMOTE":0.833,"ADAYSN":0.874,"ROS":0.854,"classweight":0.475},"RF":{"SMOTE":0.833,"ADAYSN":0.854,"ROS":0.875,"classweight":0.395},"SVM":{"SMOTE":0.72,"ADAYSN":0.854,"ROS":0.708,"classweight":0.516},"RidgeCV":{"SMOTE":0.895,"ADAYSN":0.895,"ROS":0.895,"classweight":0.575}},
           "DATA 2":{"KNN":{"SMOTE":0.834,"ADAYSN":0.851,"ROS":0.99,"classweight":0.5},"LogisticR":{"SMOTE":0.939,"ADAYSN":0.973,"ROS":0.952,"classweight":0.478},"NaivesBayes":{"SMOTE":0.904,"ADAYSN":0.921,"ROS":0.665,"classweight":0.473},"DecisionT":{"SMOTE":0.978,"ADAYSN":0.973,"ROS":0.986,"classweight":0.482},"RF":{"SMOTE":0.98,"ADAYSN":0.982,"ROS":0.995,"classweight":0.5},"SVM":{"SMOTE":0.83,"ADAYSN":0.852,"ROS":0.908,"classweight":0.645},"RidgeCV":{"SMOTE":0.973,"ADAYSN":0.978,"ROS":0.973,"classweight":0.46}},
           "DATA 3":{"KNN":{"SMOTE":0.851,"ADAYSN":0.849,"ROS":0.966,"classweight":0.512},"LogisticR":{"SMOTE":0.8,"ADAYSN":0.792,"ROS":0.802,"classweight":0.626},"NaivesBayes":{"SMOTE":0.722,"ADAYSN":0.694,"ROS":0.717,"classweight":0.701},"DecisionT":{"SMOTE":0.93,"ADAYSN":0.916,"ROS":0.959,"classweight":0.593},"RF":{"SMOTE":0.91,"ADAYSN":0.904,"ROS":0.972,"classweight":0.517},"SVM":{"SMOTE":0.747,"ADAYSN":0.741,"ROS":0.752,"classweight":0.655},"RidgeCV":{"SMOTE":0.867,"ADAYSN":0.872,"ROS":0.862,"classweight":0.668}},
           "DATA 4":{"KNN":{"SMOTE":0.909,"ADAYSN":0.893,"ROS":0.984,"classweight":0.636},"LogisticR":{"SMOTE":0.92,"ADAYSN":0.954,"ROS":0.848,"classweight":0.606},"NaivesBayes":{"SMOTE":0.893,"ADAYSN":0.833,"ROS":0.848,"classweight":0.636},"DecisionT":{"SMOTE":0.939,"ADAYSN":0.924,"ROS":0.954,"classweight":0.787},"RF":{"SMOTE":0.924,"ADAYSN":0.909,"ROS":0.969,"classweight":0.484},"SVM":{"SMOTE":0.909,"ADAYSN":0.954,"ROS":0.893,"classweight":0.666},"RidgeCV":{"SMOTE":0.984,"ADAYSN":0.984,"ROS":0.984,"classweight":0.818}},
           "DATA 5":{"KNN":{"SMOTE":0.946,"ADAYSN":0.91,"ROS":0.964,"classweight":0.446},"LogisticR":{"SMOTE":0.892,"ADAYSN":0.839,"ROS":0.857,"classweight":0.696},"NaivesBayes":{"SMOTE":0.946,"ADAYSN":0.892,"ROS":0.785,"classweight":0.821},"DecisionT":{"SMOTE":0.946,"ADAYSN":0.946,"ROS":0.982,"classweight":0.428},"RF":{"SMOTE":0.964,"ADAYSN":0.964,"ROS":0.964,"classweight":0.714},"SVM":{"SMOTE":0.928,"ADAYSN":0.964,"ROS":0.964,"classweight":0.69},"RidgeCV":{"SMOTE":0.964,"ADAYSN":0.964,"ROS":0.964,"classweight":0.607}}}
datasets=["DATA 1","DATA 2","DATA 3","DATA 4","DATA 5"]
algo=["KNN","LogisticR","NaivesBayes","DecisionT","RF","SVM","RidgeCV"]
algo1=["","KNN","LogisticR","NaivesBayes","DecisionT","RF","SVM","RidgeCV"]
resample=["SMOTE","ADAYSN","ROS","classweight"]
fig,ax=plt.subplots(1,5,figsize=(40,5))
barWidth=0.20
r1 = np.arange(7)
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3] 

for i,d in enumerate(datasets):
  l1=[]
  l2=[]
  l3=[]
  l4=[]
  for k in range(7):
    l1.append(resultauc[d][algo[k]]["SMOTE"])
  for k in range(7):
    l2.append(resultauc[d][algo[k]]["ADAYSN"])
  for k in range(7):
    l3.append(resultauc[d][algo[k]]["ROS"])
  for k in range(7):
    l4.append(resultauc[d][algo[k]]["classweight"])
  
  ax[i].bar(r1,l1,width=barWidth,label="SMOTE")
  ax[i].bar(r2,l2,width=barWidth,label="ADAYSN")
  ax[i].bar(r3,l3,width=barWidth,label="ROS")
  ax[i].bar(r4,l4,width=barWidth,label="classweight")
  ax[0].legend(loc='upper center', bbox_to_anchor=(9, 1.01),
                     ncol=1, fancybox=True, shadow=True)
  ax[i].set_title(f'{d}')
  ax[i].set_xticklabels(algo1,rotation=60)
  ax[i].set_ylabel('AUC')
  ax[0].legend()
  
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
resultauc={"DATA 1":{"KNN":{"SMOTE":75,"ADAYSN":85,"ROS":96,"classweight":80},"LogisticR":{"SMOTE":81.2,"ADAYSN":81.2,"ROS":87.5,"classweight":62},"NaivesBayes":{"SMOTE":68.75,"ADAYSN":75,"ROS":65,"classweight":76.66},"DecisionT":{"SMOTE":83.3,"ADAYSN":88,"ROS":85.5,"classweight":66},"RF":{"SMOTE":83.3,"ADAYSN":85,"ROS":87.5,"classweight":66.66},"SVM":{"SMOTE":72.9,"ADAYSN":85,"ROS":71,"classweight":73.33},"RidgeCV":{"SMOTE":89.5,"ADAYSN":90,"ROS":89.5,"classweight":66.66}},
           "DATA 2":{"KNN":{"SMOTE":83.4,"ADAYSN":85,"ROS":99,"classweight":98.33},"LogisticR":{"SMOTE":93.9,"ADAYSN":97,"ROS":95.2,"classweight":94.09},"NaivesBayes":{"SMOTE":90.43,"ADAYSN":92,"ROS":66.52,"classweight":93.18},"DecisionT":{"SMOTE":97.82,"ADAYSN":97,"ROS":98.69,"classweight":94.92},"RF":{"SMOTE":98,"ADAYSN":98,"ROS":99.5,"classweight":98.33},"SVM":{"SMOTE":85,"ADAYSN":85,"ROS":90.86,"classweight":79},"RidgeCV":{"SMOTE":97.4,"ADAYSN":98,"ROS":97.4,"classweight":90.68}},
           "DATA 3":{"KNN":{"SMOTE":85.13,"ADAYSN":85,"ROS":96.6,"classweight":91.8},"LogisticR":{"SMOTE":80,"ADAYSN":79,"ROS":80.27,"classweight":78.62},"NaivesBayes":{"SMOTE":72.2,"ADAYSN":69,"ROS":71.75,"classweight":87.09},"DecisionT":{"SMOTE":93,"ADAYSN":92,"ROS":95.94,"classweight":88.3},"RF":{"SMOTE":91,"ADAYSN":90,"ROS":97.2,"classweight":90.05},"SVM":{"SMOTE":74.29,"ADAYSN":74,"ROS":75.27,"classweight":91.79},"RidgeCV":{"SMOTE":86.75,"ADAYSN":87,"ROS":86.21,"classweight":84}},
           "DATA 4":{"KNN":{"SMOTE":91.19,"ADAYSN":89,"ROS":98.57,"classweight":90},"LogisticR":{"SMOTE":92,"ADAYSN":95,"ROS":85.23,"classweight":85},"NaivesBayes":{"SMOTE":89.52,"ADAYSN":83,"ROS":85,"classweight":89.1},"DecisionT":{"SMOTE":94.04,"ADAYSN":92,"ROS":95.71,"classweight":90},"RF":{"SMOTE":92,"ADAYSN":91,"ROS":97.14,"classweight":90},"SVM":{"SMOTE":91.9,"ADAYSN":95,"ROS":89.52,"classweight":95},"RidgeCV":{"SMOTE":98.57,"ADAYSN":98,"ROS":98.57,"classweight":95}},
           "DATA 5":{"KNN":{"SMOTE":95,"ADAYSN":91,"ROS":96.33,"classweight":78.33},"LogisticR":{"SMOTE":89.2,"ADAYSN":84,"ROS":85,"classweight":84.16},"NaivesBayes":{"SMOTE":94.33,"ADAYSN":89,"ROS":78.33,"classweight":88},"DecisionT":{"SMOTE":94.66,"ADAYSN":95,"ROS":98.33,"classweight":75},"RF":{"SMOTE":96,"ADAYSN":96,"ROS":96,"classweight":86.66},"SVM":{"SMOTE":92.6,"ADAYSN":96,"ROS":96.33,"classweight":83.33},"RidgeCV":{"SMOTE":96,"ADAYSN":96,"ROS":96,"classweight":87.5}}}
datasets=["DATA 1","DATA 2","DATA 3","DATA 4","DATA 5"]
algo=["KNN","LogisticR","NaivesBayes","DecisionT","RF","SVM","RidgeCV"]
algo1=["","KNN","LogisticR","NaivesBayes","DecisionT","RF","SVM","RidgeCV"]
resample=["SMOTE","ADAYSN","ROS","classweight"]
fig,ax=plt.subplots(1,5,figsize=(40,5))
barWidth=0.20
r1 = np.arange(7)
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3] 

for i,d in enumerate(datasets):
  l1=[]
  l2=[]
  l3=[]
  l4=[]
  for k in range(7):
    l1.append(resultauc[d][algo[k]]["SMOTE"])
  for k in range(7):
    l2.append(resultauc[d][algo[k]]["ADAYSN"])
  for k in range(7):
    l3.append(resultauc[d][algo[k]]["ROS"])
  for k in range(7):
    l4.append(resultauc[d][algo[k]]["classweight"])
  
  ax[i].bar(r1,l1,width=barWidth,label="SMOTE")
  ax[i].bar(r2,l2,width=barWidth,label="ADAYSN")
  ax[i].bar(r3,l3,width=barWidth,label="ROS")
  ax[i].bar(r4,l4,width=barWidth,label="classweight")
  ax[0].legend(loc='upper center', bbox_to_anchor=(9, 1.01),
                     ncol=1, fancybox=True, shadow=True)
  ax[i].set_title(f'{d}')
  ax[i].set_xticklabels(algo1,rotation=60)
  ax[i].set_ylabel('Accuracy')
  ax[0].legend()
  
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
resultauc={"DATA 1":{"KNN":{"SMOTE":0.75,"ADAYSN":0.85,"ROS":0.96,"classweight":0.73},"LogisticR":{"SMOTE":0.81,"ADAYSN":0.81,"ROS":0.87,"classweight":0.65},"NaivesBayes":{"SMOTE":0.73,"ADAYSN":0.75,"ROS":0.64,"classweight":0.78},"DecisionT":{"SMOTE":0.83,"ADAYSN":0.87,"ROS":0.85,"classweight":0.68},"RF":{"SMOTE":0.83,"ADAYSN":0.85,"ROS":0.87,"classweight":0.66},"SVM":{"SMOTE":0.73,"ADAYSN":0.85,"ROS":0.70,"classweight":0.72},"RidgeCV":{"SMOTE":0.90,"ADAYSN":0.89,"ROS":0.89,"classweight":0.72}},
           "DATA 2":{"KNN":{"SMOTE":0.83,"ADAYSN":0.85,"ROS":1.00,"classweight":0.97},"LogisticR":{"SMOTE":0.94,"ADAYSN":0.97,"ROS":0.95,"classweight":0.95},"NaivesBayes":{"SMOTE":0.90,"ADAYSN":0.92,"ROS":0.65,"classweight":0.95},"DecisionT":{"SMOTE":0.98,"ADAYSN":0.97,"ROS":0.99,"classweight":0.96},"RF":{"SMOTE":0.98,"ADAYSN":0.98,"ROS":1.00,"classweight":0.97},"SVM":{"SMOTE":0.85,"ADAYSN":0.85,"ROS":0.91,"classweight":0.87},"RidgeCV":{"SMOTE":0.97,"ADAYSN":0.98,"ROS":0.97,"classweight":0.93}},
           "DATA 3":{"KNN":{"SMOTE":0.85,"ADAYSN":0.85,"ROS":0.97,"classweight":0.89},"LogisticR":{"SMOTE":0.80,"ADAYSN":0.79,"ROS":0.80,"classweight":0.83},"NaivesBayes":{"SMOTE":0.71,"ADAYSN":0.69,"ROS":0.71,"classweight":0.88},"DecisionT":{"SMOTE":0.93,"ADAYSN":0.92,"ROS":0.96,"classweight":0.88},"RF":{"SMOTE":0.91,"ADAYSN":0.90,"ROS":0.97,"classweight":0.88},"SVM":{"SMOTE":0.75,"ADAYSN":0.74,"ROS":0.75,"classweight":0.91},"RidgeCV":{"SMOTE":0.87,"ADAYSN":0.87,"ROS":0.86,"classweight":0.86}},
           "DATA 4":{"KNN":{"SMOTE":0.91,"ADAYSN":0.89,"ROS":0.98,"classweight":0.89},"LogisticR":{"SMOTE":0.92,"ADAYSN":0.95,"ROS":0.85,"classweight":0.85},"NaivesBayes":{"SMOTE":0.89,"ADAYSN":0.83,"ROS":0.85,"classweight":0.89},"DecisionT":{"SMOTE":0.94,"ADAYSN":0.92,"ROS":0.95,"classweight":0.90},"RF":{"SMOTE":0.92,"ADAYSN":0.91,"ROS":0.97,"classweight":0.86},"SVM":{"SMOTE":0.91,"ADAYSN":0.95,"ROS":0.89,"classweight":0.93},"RidgeCV":{"SMOTE":0.98,"ADAYSN":0.98,"ROS":0.98,"classweight":0.94}},
           "DATA 5":{"KNN":{"SMOTE":0.95,"ADAYSN":0.91,"ROS":0.96,"classweight":0.77},"LogisticR":{"SMOTE":0.89,"ADAYSN":0.84,"ROS":0.85,"classweight":0.85},"NaivesBayes":{"SMOTE":0.95,"ADAYSN":0.89,"ROS":0.78,"classweight":0.89},"DecisionT":{"SMOTE":0.95,"ADAYSN":0.95,"ROS":0.98,"classweight":0.75},"RF":{"SMOTE":0.96,"ADAYSN":0.96,"ROS":0.96,"classweight":0.88},"SVM":{"SMOTE":0.93,"ADAYSN":0.96,"ROS":0.96,"classweight":0.85},"RidgeCV":{"SMOTE":0.96,"ADAYSN":0.96,"ROS":0.96,"classweight":0.86}}}
datasets=["DATA 1","DATA 2","DATA 3","DATA 4","DATA 5"]
algo=["KNN","LogisticR","NaivesBayes","DecisionT","RF","SVM","RidgeCV"]
algo1=["","KNN","LogisticR","NaivesBayes","DecisionT","RF","SVM","RidgeCV"]
resample=["SMOTE","ADAYSN","ROS","classweight"]
fig,ax=plt.subplots(1,5,figsize=(40,5))
barWidth=0.20
r1 = np.arange(7)
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3] 

for i,d in enumerate(datasets):
  l1=[]
  l2=[]
  l3=[]
  l4=[]
  for k in range(7):
    l1.append(resultauc[d][algo[k]]["SMOTE"])
  for k in range(7):
    l2.append(resultauc[d][algo[k]]["ADAYSN"])
  for k in range(7):
    l3.append(resultauc[d][algo[k]]["ROS"])
  for k in range(7):
    l4.append(resultauc[d][algo[k]]["classweight"])
  
  ax[i].bar(r1,l1,width=barWidth,label="SMOTE")
  ax[i].bar(r2,l2,width=barWidth,label="ADAYSN")
  ax[i].bar(r3,l3,width=barWidth,label="ROS")
  ax[i].bar(r4,l4,width=barWidth,label="classweight")
  ax[0].legend(loc='upper center', bbox_to_anchor=(9, 1.01),
                     ncol=1, fancybox=True, shadow=True)
  ax[i].set_title(f'{d}')
  ax[i].set_xticklabels(algo1,rotation=60)
  ax[i].set_ylabel('F1-Score')
  ax[0].legend()
  
plt.show()
